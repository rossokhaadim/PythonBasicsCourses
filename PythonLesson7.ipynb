# %% [markdown]
# ## ДЗ складається з 2ох частин:
# 1) Відпрацювання циклу for
#
# 2) Робота з pycharm

# %% [markdown]
# # Частина 1. Цикли

# %% [markdown]
# ## Завдання 1
#
# > Розминка. Підрахуй суму всіх чисел в діапазоні від 1 до заданого числа

# %%
from random import randint

# %%
random_num = randint(100, 500)
s = 0
for i in range(1, random_num+1):
  s+=i
print(f'{random_num=} sum={s}')
# Out:
# random_num=108 sum=5886

# %% [markdown]
# ## Завдання 2
#
# > Загублена нагорода. Є дві змінні films_title зберігає назви фільмів, films_awards список нагород ОДНОГО з цих фільмів. Задача: створити нову змінну яка збереже назву фільму та всі його номінації. ВИКОРИСТАЙ ЦИКЛ FOR

# %%
films_title = {
    "results": [
        {
            "imdb_id": "tt1201607",
            "title": ""
        },
        {
            "imdb_id": "tt0241527",
            "title": "Harry Potter and the Sorcerer's Stone"
        },
        {
            "imdb_id": "tt0926084",
            "title": "Harry Potter and the Deathly Hallows: Part 1"
        },
        {
            "imdb_id": "tt0304141",
            "title": "Harry Potter and the Prisoner of Azkaban"
        },
        {
            "imdb_id": "tt0417741",
            "title": "Harry Potter and the Half-Blood Prince"
        },
        {
            "imdb_id": "tt0295297",
            "title": "Harry Potter and the Chamber of Secrets"
        },
        {
            "imdb_id": "tt0330373",
            "title": "Harry Potter and the Goblet of Fire"
        },
        {
            "imdb_id": "tt0373889",
            "title": "Harry Potter and the Order of the Phoenix"
        }
    ]
}

film_awards = {
    "links": {
        "next": None,
        "previous": None
    },
    "count": 49,
    "results": [
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [
                {
                    "imdb_id": "nm0240183",
                    "name": "Nick Dudman"
                },
                {
                    "imdb_id": "nm0460792",
                    "name": "Amanda Knight"
                },
                {
                    "imdb_id": "nm0866566",
                    "name": "Lisa Tomblin"
                }
            ],
            "event_name": "Academy Awards, USA",
            "year": 2012,
            "type": "Nominee",
            "award_name": "Oscar",
            "award": "Best Achievement in Makeup"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [
                {
                    "imdb_id": "nm0121888",
                    "name": "Tim Burke"
                },
                {
                    "imdb_id": "nm0724624",
                    "name": "John Richardson"
                },
                {
                    "imdb_id": "nm0124935",
                    "name": "Greg Butler"
                },
                {
                    "imdb_id": "nm1316134",
                    "name": "David Vickery"
                }
            ],
            "event_name": "BAFTA Awards",
            "year": 2012,
            "type": "Winner",
            "award_name": "BAFTA Film Award",
            "award": "Best Special Visual Effects"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [
                {
                    "imdb_id": "nm0946734",
                    "name": "David Yates"
                },
                {
                    "imdb_id": "nm0746830",
                    "name": "J.K. Rowling"
                },
                {
                    "imdb_id": "nm0057655",
                    "name": "David Barron"
                },
                {
                    "imdb_id": "nm0382268",
                    "name": "David Heyman"
                }
            ],
            "event_name": "BAFTA Awards",
            "year": 2011,
            "type": "Winner",
            "award_name": "BAFTA Children's Award",
            "award": "Best Feature Film"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [
                {
                    "imdb_id": "nm1168404",
                    "name": "Reg Wayment"
                },
                {
                    "imdb_id": "nm0621178",
                    "name": "Daniel Naprous"
                },
                {
                    "imdb_id": "nm2823677",
                    "name": "Calvin Warrington-Heasman"
                },
                {
                    "imdb_id": "nm1497190",
                    "name": "Michael Byrch"
                },
                {
                    "imdb_id": "nm0169512",
                    "name": "Jonathan Cohen"
                },
                {
                    "imdb_id": "nm0806905",
                    "name": "C.C. Smiff"
                },
                {
                    "imdb_id": "nm0006976",
                    "name": "Marc Cass"
                },
                {
                    "imdb_id": "nm0587215",
                    "name": "Peter Miles"
                },
                {
                    "imdb_id": "nm0494749",
                    "name": "Derek Lea"
                },
                {
                    "imdb_id": "nm3470481",
                    "name": "Adam Brashaw"
                },
                {
                    "imdb_id": "nm1164477",
                    "name": "Bradley Farmer"
                },
                {
                    "imdb_id": "nm0188836",
                    "name": "David Cronnelly"
                },
                {
                    "imdb_id": "nm0695689",
                    "name": "Dominic Preece"
                },
                {
                    "imdb_id": "nm1176120",
                    "name": "Lee Millham"
                },
                {
                    "imdb_id": "nm4447854",
                    "name": "Lewis Young"
                },
                {
                    "imdb_id": "nm2824044",
                    "name": "Marlow Warrington-Mattei"
                },
                {
                    "imdb_id": "nm1946831",
                    "name": "Matthew Stirling"
                },
                {
                    "imdb_id": "nm0497856",
                    "name": "Maurice Lee"
                },
                {
                    "imdb_id": "nm1034968",
                    "name": "Peter White"
                },
                {
                    "imdb_id": "nm0257670",
                    "name": "Rick English"
                },
                {
                    "imdb_id": "nm0402615",
                    "name": "Rob Hunt"
                },
                {
                    "imdb_id": "nm0408449",
                    "name": "Rob Inch"
                },
                {
                    "imdb_id": "nm2213734",
                    "name": "Roy Taylor"
                },
                {
                    "imdb_id": "nm3767640",
                    "name": "Tilly Powell"
                },
                {
                    "imdb_id": "nm3479192",
                    "name": "Bobby Holland Hanton"
                },
                {
                    "imdb_id": "nm0020788",
                    "name": "Lucy Allen"
                },
                {
                    "imdb_id": "nm1747251",
                    "name": "Mark Archer"
                },
                {
                    "imdb_id": "nm0021974",
                    "name": "Nina Armstrong"
                },
                {
                    "imdb_id": "nm1020873",
                    "name": "Gary Arthurs"
                },
                {
                    "imdb_id": "nm3254607",
                    "name": "Helen Steinway Bailey"
                },
                {
                    "imdb_id": "nm3764885",
                    "name": "Nellie Burroughes"
                },
                {
                    "imdb_id": "nm0103525",
                    "name": "Richard Bradshaw"
                },
                {
                    "imdb_id": "nm1171015",
                    "name": "Bruce Cain"
                },
                {
                    "imdb_id": "nm4570675",
                    "name": "Annabel Canaven"
                },
                {
                    "imdb_id": "nm1359252",
                    "name": "Nick Chopping"
                },
                {
                    "imdb_id": "nm2351723",
                    "name": "Talila Craig"
                },
                {
                    "imdb_id": "nm0189837",
                    "name": "Graeme Crowther"
                },
                {
                    "imdb_id": "nm0193297",
                    "name": "Clive Curtis"
                },
                {
                    "imdb_id": "nm1966810",
                    "name": "Nicholas Daines"
                },
                {
                    "imdb_id": "nm0212548",
                    "name": "Ray De-Haan"
                },
                {
                    "imdb_id": "nm5359732",
                    "name": "Sam Dent"
                },
                {
                    "imdb_id": "nm0235695",
                    "name": "Jim Dowdall"
                },
                {
                    "imdb_id": "nm0248866",
                    "name": "Tracey Eddon"
                },
                {
                    "imdb_id": "nm0249276",
                    "name": "Jamie Edgell"
                },
                {
                    "imdb_id": "nm1338287",
                    "name": "Dave Fisher"
                },
                {
                    "imdb_id": "nm2766440",
                    "name": "Pete Ford"
                },
                {
                    "imdb_id": "nm0285630",
                    "name": "Elaine Ford"
                },
                {
                    "imdb_id": "nm0287674",
                    "name": "Amanda Foster"
                },
                {
                    "imdb_id": "nm0291897",
                    "name": "Sarah Franzl"
                },
                {
                    "imdb_id": "nm6228952",
                    "name": "Grace Franzl"
                },
                {
                    "imdb_id": "nm2431708",
                    "name": "Aldonio Danny Frietas"
                },
                {
                    "imdb_id": "nm1247272",
                    "name": "James Grogan"
                },
                {
                    "imdb_id": "nm0387614",
                    "name": "Nick Hobbs"
                },
                {
                    "imdb_id": "nm1088505",
                    "name": "David Holmes"
                },
                {
                    "imdb_id": "nm0404497",
                    "name": "Eunice Huthart"
                },
                {
                    "imdb_id": "nm0410034",
                    "name": "Rowley Irlam"
                },
                {
                    "imdb_id": "nm1631545",
                    "name": "Ian Kay"
                },
                {
                    "imdb_id": "nm1293030",
                    "name": "Tolga Kenan"
                },
                {
                    "imdb_id": "nm0416209",
                    "name": "Mike Lambert"
                },
                {
                    "imdb_id": "nm3118567",
                    "name": "Nicholas Lewis"
                },
                {
                    "imdb_id": "nm0971051",
                    "name": "Paul Lowe"
                },
                {
                    "imdb_id": "nm0524706",
                    "name": "Tony Lucken"
                },
                {
                    "imdb_id": "nm1595516",
                    "name": "Marc Mailley"
                },
                {
                    "imdb_id": "nm1661740",
                    "name": "Kai Martin"
                },
                {
                    "imdb_id": "nm0556456",
                    "name": "Tina Maskell"
                },
                {
                    "imdb_id": "nm0572222",
                    "name": "Jo McLaren"
                },
                {
                    "imdb_id": "nm1176074",
                    "name": "Kim McGarrity"
                },
                {
                    "imdb_id": "nm0571791",
                    "name": "Nick McKinless"
                },
                {
                    "imdb_id": "nm1915835",
                    "name": "Russell MacLeod"
                },
                {
                    "imdb_id": "nm1776730",
                    "name": "Jamie Millington"
                },
                {
                    "imdb_id": "nm2050354",
                    "name": "Sian Milne"
                },
                {
                    "imdb_id": "nm0609561",
                    "name": "Mark Mottram"
                },
                {
                    "imdb_id": "nm2956073",
                    "name": "David Newton"
                },
                {
                    "imdb_id": "nm0630003",
                    "name": "Brian Nickels"
                },
                {
                    "imdb_id": "nm0640769",
                    "name": "James O'Donnell"
                },
                {
                    "imdb_id": "nm1794098",
                    "name": "Justin Pearson"
                },
                {
                    "imdb_id": "nm0670092",
                    "name": "Peter Pedrero"
                },
                {
                    "imdb_id": "nm2603450",
                    "name": "Andy Pilgrim"
                },
                {
                    "imdb_id": "nm2974954",
                    "name": "Chris Pollard"
                },
                {
                    "imdb_id": "nm0693325",
                    "name": "Mike Potter"
                },
                {
                    "imdb_id": "nm0694128",
                    "name": "Greg Powell"
                },
                {
                    "imdb_id": "nm6633887",
                    "name": "Kierron Quest"
                },
                {
                    "imdb_id": "nm1245695",
                    "name": "Alison Ryan"
                },
                {
                    "imdb_id": "nm2432897",
                    "name": "Marcus Shakesheff"
                },
                {
                    "imdb_id": "nm0132711",
                    "name": "Marvin Campbell"
                },
                {
                    "imdb_id": "nm2092723",
                    "name": "Ryan Stuart"
                },
                {
                    "imdb_id": "nm0853092",
                    "name": "Rocky Taylor"
                },
                {
                    "imdb_id": "nm0887991",
                    "name": "Tony Van Silva"
                },
                {
                    "imdb_id": "nm1361152",
                    "name": "Andy Wareham"
                },
                {
                    "imdb_id": "nm0922916",
                    "name": "Bill Weston"
                },
                {
                    "imdb_id": "nm2196337",
                    "name": "Maxine Whittaker"
                },
                {
                    "imdb_id": "nm0924939",
                    "name": "Jason White"
                },
                {
                    "imdb_id": "nm1603069",
                    "name": "Joanna Whitney"
                },
                {
                    "imdb_id": "nm4031647",
                    "name": "Martin Wilde"
                },
                {
                    "imdb_id": "nm2064879",
                    "name": "Donna Williams"
                }
            ],
            "event_name": "Screen Actors Guild Awards",
            "year": 2012,
            "type": "Winner",
            "award_name": "Actor",
            "award": "Outstanding Performance by a Stunt Ensemble in a Motion Picture"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [],
            "event_name": "Academy of Science Fiction, Fantasy & Horror Films, USA",
            "year": 2012,
            "type": "Winner",
            "award_name": "Saturn Award",
            "award": "Best Fantasy Film"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [
                {
                    "imdb_id": "/title/tt0241527",
                    "name": "Harry Potter and the Sorcerer's Stone"
                },
                {
                    "imdb_id": "/title/tt0295297",
                    "name": "Harry Potter and the Chamber of Secrets"
                },
                {
                    "imdb_id": "/title/tt0304141",
                    "name": "Harry Potter and the Prisoner of Azkaban"
                },
                {
                    "imdb_id": "/title/tt0330373",
                    "name": "Harry Potter and the Goblet of Fire"
                },
                {
                    "imdb_id": "/title/tt0373889",
                    "name": "Harry Potter and the Order of the Phoenix"
                },
                {
                    "imdb_id": "/title/tt0417741",
                    "name": "Harry Potter and the Half-Blood Prince"
                },
                {
                    "imdb_id": "/title/tt0926084",
                    "name": ""
                }
            ],
            "event_name": "AFI Awards, USA",
            "year": 2012,
            "type": "Winner",
            "award_name": "Special Award",
            "award": "For"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [
                {
                    "imdb_id": "nm0000614",
                    "name": "Alan Rickman"
                }
            ],
            "event_name": "Alliance of Women Film Journalists",
            "year": 2012,
            "type": "Nominee",
            "award_name": "EDA Award",
            "award": "Best Supporting Actor"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [
                {
                    "imdb_id": "nm0946734",
                    "name": "David Yates"
                },
                {
                    "imdb_id": "nm0460141",
                    "name": "Steve Kloves"
                },
                {
                    "imdb_id": "nm0746830",
                    "name": "J.K. Rowling"
                },
                {
                    "imdb_id": "nm0057655",
                    "name": "David Barron"
                },
                {
                    "imdb_id": "nm0382268",
                    "name": "David Heyman"
                },
                {
                    "imdb_id": "/title/tt0241527",
                    "name": "Harry Potter and the Sorcerer's Stone"
                },
                {
                    "imdb_id": "/title/tt0295297",
                    "name": "Harry Potter and the Chamber of Secrets"
                },
                {
                    "imdb_id": "/title/tt0304141",
                    "name": "Harry Potter and the Prisoner of Azkaban"
                },
                {
                    "imdb_id": "/title/tt0330373",
                    "name": "Harry Potter and the Goblet of Fire"
                },
                {
                    "imdb_id": "/title/tt0373889",
                    "name": "Harry Potter and the Order of the Phoenix"
                },
                {
                    "imdb_id": "/title/tt0417741",
                    "name": "Harry Potter and the Half-Blood Prince"
                },
                {
                    "imdb_id": "/title/tt0926084",
                    "name": ""
                },
                {
                    "imdb_id": "nm0001060",
                    "name": "Chris Columbus"
                },
                {
                    "imdb_id": "nm0001565",
                    "name": "Mike Newell"
                },
                {
                    "imdb_id": "nm0190859",
                    "name": "Alfonso Cuarón"
                },
                {
                    "imdb_id": "nm0325533",
                    "name": "Michael Goldenberg"
                },
                {
                    "imdb_id": "nm0186023",
                    "name": "Stuart Craig"
                },
                {
                    "imdb_id": "nm0483678",
                    "name": "Neil Lamont"
                },
                {
                    "imdb_id": "nm0573328",
                    "name": "Stephenie McMillan"
                }
            ],
            "event_name": "Art Directors Guild",
            "year": 2012,
            "type": "Winner",
            "award_name": "Contribution to Cinematic Imagery Award",
            "award": ""
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [],
            "event_name": "Awards Circuit Community Awards",
            "year": 2011,
            "type": "Winner",
            "award_name": "ACCA",
            "award": "Best Achievement in Visual Effects"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [
                {
                    "imdb_id": "nm0006035",
                    "name": "Alexandre Desplat"
                }
            ],
            "event_name": "BMI Film & TV Awards",
            "year": 2012,
            "type": "Winner",
            "award_name": "BMI Film Music Award",
            "award": "Film Music"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [
                {
                    "imdb_id": "/title/tt0241527",
                    "name": "Harry Potter and the Sorcerer's Stone"
                },
                {
                    "imdb_id": "/title/tt0295297",
                    "name": "Harry Potter and the Chamber of Secrets"
                },
                {
                    "imdb_id": "/title/tt0304141",
                    "name": "Harry Potter and the Prisoner of Azkaban"
                },
                {
                    "imdb_id": "/title/tt0330373",
                    "name": "Harry Potter and the Goblet of Fire"
                },
                {
                    "imdb_id": "/title/tt0373889",
                    "name": "Harry Potter and the Order of the Phoenix"
                },
                {
                    "imdb_id": "/title/tt0417741",
                    "name": "Harry Potter and the Half-Blood Prince"
                },
                {
                    "imdb_id": "/title/tt0926084",
                    "name": ""
                }
            ],
            "event_name": "Broadcast Film Critics Association Awards",
            "year": 2013,
            "type": "Nominee",
            "award_name": "Critics Choice Award",
            "award": "Favorite Film Franchise"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [],
            "event_name": "Broadcast Film Critics Association Awards",
            "year": 2012,
            "type": "Winner",
            "award_name": "Critics Choice Award",
            "award": "Best Sound"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [
                {
                    "imdb_id": "nm0278973",
                    "name": "Jany Temime"
                }
            ],
            "event_name": "Costume Designers Guild Awards",
            "year": 2012,
            "type": "Winner",
            "award_name": "CDG Award",
            "award": "Excellence in Fantasy Film"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [
                {
                    "imdb_id": "nm0006035",
                    "name": "Alexandre Desplat"
                }
            ],
            "event_name": "Denver Film Critics Society",
            "year": 2012,
            "type": "Nominee",
            "award_name": "DFCS Award",
            "award": "Best Original Score"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [
                {
                    "imdb_id": "nm0946734",
                    "name": "David Yates"
                }
            ],
            "event_name": "Empire Awards, UK",
            "year": 2012,
            "type": "Winner",
            "award_name": "Empire Award",
            "award": "Best Director"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [],
            "event_name": "Evening Standard British Film Awards",
            "year": 2012,
            "type": "Winner",
            "award_name": "Evening Standard British Film Award",
            "award": "Blockbuster of the Year"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [
                {
                    "imdb_id": "nm0240183",
                    "name": "Nick Dudman"
                },
                {
                    "imdb_id": "nm0460792",
                    "name": "Amanda Knight"
                },
                {
                    "imdb_id": "nm0866566",
                    "name": "Lisa Tomblin"
                }
            ],
            "event_name": "Gold Derby Awards",
            "year": 2012,
            "type": "Winner",
            "award_name": "Gold Derby Award",
            "award": "Makeup/Hair"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [],
            "event_name": "Golden Schmoes Awards",
            "year": 2011,
            "type": "Nominee",
            "award_name": "Golden Schmoes",
            "award": "Best Special Effects of the Year"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [
                {
                    "imdb_id": "/company/co0002663",
                    "name": "Warner Bros."
                },
                {
                    "imdb_id": "/company/co0027697",
                    "name": "Aspect Ratio"
                }
            ],
            "event_name": "Golden Trailer Awards",
            "year": 2012,
            "type": "Nominee",
            "award_name": "Golden Trailer",
            "award": "Best Action TV Spot"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [
                {
                    "imdb_id": "nm0006035",
                    "name": "Alexandre Desplat"
                }
            ],
            "event_name": "Grammy Awards",
            "year": 2012,
            "type": "Nominee",
            "award_name": "Grammy",
            "award": "Best Score Soundtrack for Visual Media"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [],
            "event_name": "Hollywood Film Awards",
            "year": 2011,
            "type": "Winner",
            "award_name": "Hollywood Movie Award",
            "award": ""
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [
                {
                    "imdb_id": "nm0006035",
                    "name": "Alexandre Desplat"
                }
            ],
            "event_name": "Houston Film Critics Society Awards",
            "year": 2011,
            "type": "Nominee",
            "award_name": "HFCS Award",
            "award": "Best Original Score"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [
                {
                    "imdb_id": "nm0946734",
                    "name": "David Yates"
                },
                {
                    "imdb_id": "nm0460141",
                    "name": "Steve Kloves"
                }
            ],
            "event_name": "Hugo Awards",
            "year": 2012,
            "type": "Nominee",
            "award_name": "Hugo",
            "award": "Best Dramatic Presentation - Long Form"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [],
            "event_name": "IGN Summer Movie Awards",
            "year": 2011,
            "type": "Winner",
            "award_name": "IGN Award",
            "award": "Best Fantasy Movie"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [
                {
                    "imdb_id": "nm0006035",
                    "name": "Alexandre Desplat"
                }
            ],
            "event_name": "International Film Music Critics Award (IFMCA)",
            "year": 2012,
            "type": "Nominee",
            "award_name": "IFMCA Award",
            "award": "Best Original Score for a Fantasy/Science Fiction/Horror Film"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [],
            "event_name": "International Online Cinema Awards (INOCA)",
            "year": 2012,
            "type": "Nominee",
            "award_name": "INOCA",
            "award": "Best Visual Effects"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [],
            "event_name": "Italian Online Movie Awards (IOMA)",
            "year": 2012,
            "type": "Nominee",
            "award_name": "IOMA",
            "award": "Best Special Effects (Migliori effetti speciali)"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [
                {
                    "imdb_id": "nm0946734",
                    "name": "David Yates"
                }
            ],
            "event_name": "Jupiter Award",
            "year": 2012,
            "type": "Winner",
            "award_name": "Jupiter Award",
            "award": "Best International Film"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [
                {
                    "imdb_id": "nm0705356",
                    "name": "Daniel Radcliffe"
                }
            ],
            "event_name": "Kids' Choice Awards, USA",
            "year": 2012,
            "type": "Nominee",
            "award_name": "Blimp Award",
            "award": "Favorite Movie Actor"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [
                {
                    "imdb_id": "nm0705356",
                    "name": "Daniel Radcliffe"
                }
            ],
            "event_name": "MTV Movie + TV Awards",
            "year": 2012,
            "type": "Winner",
            "award_name": "MTV Movie Award",
            "award": "Best Hero"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [],
            "event_name": "National Board of Review, USA",
            "year": 2011,
            "type": "Winner",
            "award_name": "NBR Award",
            "award": "Top Films"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [
                {
                    "imdb_id": "nm0183418",
                    "name": "Mark Coulier"
                },
                {
                    "imdb_id": "nm0240183",
                    "name": "Nick Dudman"
                },
                {
                    "imdb_id": "nm0460792",
                    "name": "Amanda Knight"
                },
                {
                    "imdb_id": "nm0866566",
                    "name": "Lisa Tomblin"
                },
                {
                    "imdb_id": "nm2247761",
                    "name": "Claire Green"
                },
                {
                    "imdb_id": "nm2681696",
                    "name": "Charlotte Hayward"
                },
                {
                    "imdb_id": "nm0418749",
                    "name": "Duncan Jarman"
                },
                {
                    "imdb_id": "nm1390452",
                    "name": "Chris Lyons"
                },
                {
                    "imdb_id": "nm0974195",
                    "name": "Stephen Murphy"
                },
                {
                    "imdb_id": "nm4380350",
                    "name": "Helen Rowe"
                }
            ],
            "event_name": "Online Film & Television Association",
            "year": 2012,
            "type": "Nominee",
            "award_name": "OFTA Film Award",
            "award": "Best Makeup and Hairstyling"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [
                {
                    "imdb_id": "/title/tt0241527",
                    "name": "Harry Potter and the Sorcerer's Stone"
                },
                {
                    "imdb_id": "/title/tt0295297",
                    "name": "Harry Potter and the Chamber of Secrets"
                },
                {
                    "imdb_id": "/title/tt0304141",
                    "name": "Harry Potter and the Prisoner of Azkaban"
                },
                {
                    "imdb_id": "/title/tt0330373",
                    "name": "Harry Potter and the Goblet of Fire"
                },
                {
                    "imdb_id": "/title/tt0373889",
                    "name": "Harry Potter and the Order of the Phoenix"
                },
                {
                    "imdb_id": "/title/tt0417741",
                    "name": "Harry Potter and the Half-Blood Prince"
                },
                {
                    "imdb_id": "/title/tt0926084",
                    "name": ""
                }
            ],
            "event_name": "People's Choice Awards, USA",
            "year": 2013,
            "type": "Nominee",
            "award_name": "People's Choice Award",
            "award": "Favorite Move Fan Following"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [],
            "event_name": "People's Choice Awards, USA",
            "year": 2012,
            "type": "Winner",
            "award_name": "People's Choice Award",
            "award": "Favorite Movie"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [
                {
                    "imdb_id": "nm0186023",
                    "name": "Stuart Craig"
                }
            ],
            "event_name": "Phoenix Film Critics Society Awards",
            "year": 2011,
            "type": "Nominee",
            "award_name": "PFCS Award",
            "award": "Best Production Design"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [],
            "event_name": "Rembrandt Awards",
            "year": 2012,
            "type": "Winner",
            "award_name": "Rembrandt Award",
            "award": "Best International Film (Beste Buitenlandse Film)"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [
                {
                    "imdb_id": "nm0946734",
                    "name": "David Yates"
                }
            ],
            "event_name": "Rondo Hatton Classic Horror Awards",
            "year": 2011,
            "type": "Nominee",
            "award_name": "Rondo Statuette",
            "award": "Best Film"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [],
            "event_name": "Russian National Movie Awards",
            "year": 2012,
            "type": "Nominee",
            "award_name": "Georges Award",
            "award": "Best Foreign Drama of the Year"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [
                {
                    "imdb_id": "nm0006035",
                    "name": "Alexandre Desplat"
                }
            ],
            "event_name": "San Diego Film Critics Society Awards",
            "year": 2011,
            "type": "Winner",
            "award_name": "SDFCS Award",
            "award": "Best Score"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [
                {
                    "imdb_id": "nm0006035",
                    "name": "Alexandre Desplat"
                }
            ],
            "event_name": "Satellite Awards",
            "year": 2011,
            "type": "Nominee",
            "award_name": "Satellite Award",
            "award": "Best Original Score"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [],
            "event_name": "Scream Awards",
            "year": 2011,
            "type": "Winner",
            "award_name": "Scream Award",
            "award": "The Ultimate Scream"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [],
            "event_name": "SFX Awards, UK",
            "year": 2012,
            "type": "Winner",
            "award_name": "SFX Award",
            "award": "Best Film"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [
                {
                    "imdb_id": "nm0121888",
                    "name": "Tim Burke"
                },
                {
                    "imdb_id": "nm0724624",
                    "name": "John Richardson"
                },
                {
                    "imdb_id": "nm0124935",
                    "name": "Greg Butler"
                },
                {
                    "imdb_id": "nm1316134",
                    "name": "David Vickery"
                }
            ],
            "event_name": "St. Louis Film Critics Association, US",
            "year": 2011,
            "type": "Winner",
            "award_name": "SLFCA Award",
            "award": "Best Visual Effects"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [
                {
                    "imdb_id": "nm0000146",
                    "name": "Ralph Fiennes"
                },
                {
                    "imdb_id": "nm0705356",
                    "name": "Daniel Radcliffe"
                }
            ],
            "event_name": "Teen Choice Awards",
            "year": 2012,
            "type": "Winner",
            "award_name": "Teen Choice Award",
            "award": "Choice Movie: Fight"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [],
            "event_name": "Teen Choice Awards",
            "year": 2011,
            "type": "Winner",
            "award_name": "Teen Choice Award",
            "award": "Choice Summer Movie"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [
                {
                    "imdb_id": "nm0698905",
                    "name": "Mike Proudfoot"
                }
            ],
            "event_name": "The Operators Award",
            "year": 2011,
            "type": "Winner",
            "award_name": "The Operators Award",
            "award": "Feature Film"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [
                {
                    "imdb_id": "nm2120594",
                    "name": "Michele Benigna"
                },
                {
                    "imdb_id": "nm1974602",
                    "name": "Martin Ciastko"
                },
                {
                    "imdb_id": "nm1346072",
                    "name": "Thomas Dyg"
                },
                {
                    "imdb_id": "nm0732369",
                    "name": "Andy Robinson"
                }
            ],
            "event_name": "Visual Effects Society Awards",
            "year": 2012,
            "type": "Nominee",
            "award_name": "VES Award",
            "award": "Outstanding Compositing in a Feature Motion Picture"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [
                {
                    "imdb_id": "nm0186023",
                    "name": "Stuart Craig"
                },
                {
                    "imdb_id": "nm0573328",
                    "name": "Stephenie McMillan"
                }
            ],
            "event_name": "Washington DC Area Film Critics Association Awards",
            "year": 2011,
            "type": "Nominee",
            "award_name": "WAFCA Award",
            "award": "Best Art Direction"
        },
        {
            "movie": {
                "imdb_id": "tt1201607",
                "title": ""
            },
            "series": None,
            "actor": [
                {
                    "imdb_id": "/title/tt0926084",
                    "name": ""
                },
                {
                    "imdb_id": "nm0006035",
                    "name": "Alexandre Desplat"
                },
                {
                    "imdb_id": "/title/tt1554091",
                    "name": "A Better Life"
                },
                {
                    "imdb_id": "/title/tt1322333",
                    "name": "Largo Winch II"
                },
                {
                    "imdb_id": "/title/tt1504320",
                    "name": "The King's Speech"
                },
                {
                    "imdb_id": "/title/tt0478304",
                    "name": "The Tree of Life"
                },
                {
                    "imdb_id": "/title/tt1473063",
                    "name": "La fille du puisatier"
                }
            ],
            "event_name": "World Soundtrack Awards",
            "year": 2011,
            "type": "Winner",
            "award_name": "World Soundtrack Award",
            "award": "Soundtrack Composer of the Year"
        }
    ]
}

# %%
film_info=[]
k = -1
for title in films_title['results']:
  for titlee in film_awards['results']:
    if title['title'] == titlee['movie']['title']:
      film_info.append(title['title'])
      break
for award in film_awards['results']:
  for key, value in award.items():
    if key == 'type' and value=='Nominee':
      k = 1
      continue
    if k>0:
      k-=1
      continue
    if k == 0:
      film_info.append(value)
      k=-1
print(film_info)
# Out:
# ['', 'Best Achievement in Makeup', 'Best Supporting Actor', 'Favorite Film Franchise', 'Best Original Score', 'Best Special Effects of the Year', 'Best Action TV Spot', 'Best Score Soundtrack for Visual Media', 'Best Original Score', 'Best Dramatic Presentation - Long Form', 'Best Original Score for a Fantasy/Science Fiction/Horror Film', 'Best Visual Effects', 'Best Special Effects (Migliori effetti speciali)', 'Favorite Movie Actor', 'Best Makeup and Hairstyling', 'Favorite Move Fan Following', 'Best Production Design', 'Best Film', 'Best Foreign Drama of the Year', 'Best Original Score', 'Outstanding Compositing in a Feature Motion Picture', 'Best Art Direction']

# %% [markdown]
# ## Завдання 3
#
# > Задача: створити нову змінну яка збереже назву фільму та всі нагороди що фільм виграв, рік проведення, назву конкурсу. ВИКОРИСТАЙ ЦИКЛ FOR

# %%
l=0
all_info = []
all_info.append(film_info[0])
for elem in film_awards['results']:
  if type(elem) == dict:
   for key, value in elem.items():
     if key == 'event_name': event = value
     if key == 'year': year = value
     if key == 'type' and value == 'Winner': l=1
     if key == 'type' and value != 'Winner': l=0
     if key == 'award_name' and l == 1:
      all_info.append(value)
      all_info.append(year)
      all_info.append(event)
print(all_info)
# Out:
# ['', 'BAFTA Film Award', 2012, 'BAFTA Awards', "BAFTA Children's Award", 2011, 'BAFTA Awards', 'Actor', 2012, 'Screen Actors Guild Awards', 'Saturn Award', 2012, 'Academy of Science Fiction, Fantasy & Horror Films, USA', 'Special Award', 2012, 'AFI Awards, USA', 'Contribution to Cinematic Imagery Award', 2012, 'Art Directors Guild', 'ACCA', 2011, 'Awards Circuit Community Awards', 'BMI Film Music Award', 2012, 'BMI Film & TV Awards', 'Critics Choice Award', 2012, 'Broadcast Film Critics Association Awards', 'CDG Award', 2012, 'Costume Designers Guild Awards', 'Empire Award', 2012, 'Empire Awards, UK', 'Evening Standard British Film Award', 2012, 'Evening Standard British Film Awards', 'Gold Derby Award', 2012, 'Gold Derby Awards', 'Hollywood Movie Award', 2011, 'Hollywood Film Awards', 'IGN Award', 2011, 'IGN Summer Movie Awards', 'Jupiter Award', 2012, 'Jupiter Award', 'MTV Movie Award', 2012, 'MTV Movie + TV Awards', 'NBR Award', 2011, 'National Board of Review, USA', "People's Choice Award", 2012, "People's Choice Awards, USA", 'Rembrandt Award', 2012, 'Rembrandt Awards', 'SDFCS Award', 2011, 'San Diego Film Critics Society Awards', 'Scream Award', 2011, 'Scream Awards', 'SFX Award', 2012, 'SFX Awards, UK', 'SLFCA Award', 2011, 'St. Louis Film Critics Association, US', 'Teen Choice Award', 2012, 'Teen Choice Awards', 'Teen Choice Award', 2011, 'Teen Choice Awards', 'The Operators Award', 2011, 'The Operators Award', 'World Soundtrack Award', 2011, 'World Soundtrack Awards']

# %% [markdown]
# ## Завдання 4
#
# > Задача: створити нову змінну яка всі нагороди де був номінантом Денієл Редкліфф. ВИКОРИСТАЙ ЦИКЛ FOR

# %%
number=0
s=0
for elem in film_awards['results']:
  if type(elem) == dict:
    for key,value in elem.items():
      if(key == 'actor'):
        for el in value:
          if(type(el) == dict):
            if el['name'] == 'Daniel Radcliffe': s = 1
      if(key == 'type' and value == 'Nominee' and s == 1):
        number += 1
        s = 0
      elif(key == 'type'): s=0
print(number)
# Out:
# 1

# %% [markdown]
# ## Завдання 5
#
# > Задача: підрахуйте скільки разів філм був номінантом, виграні нагороди не рахувати. ВИКОРИСТАЙ ЦИКЛ FOR

# %%
num = 0
for el in film_awards['results']:
  if type(el) == dict:
    for key, value in el.items():
      if value == 'Nominee':num+=1
print(num)
# Out:
# 21

# %% [markdown]
# # Частина 2. Pycharm

# %% [markdown]
# ## Завдання 1
#
#
# > Створіть новий проект в pycharm

# %% [markdown]
# > Переконайтеся, що у вашому роекті є віртуальне середовище в папці venv
# ![Screenshot from 2022-12-25 13-51-39.png](data:image/png;base64,...)

# %% [markdown]
# [текст посилання](https:// [текст посилання](https:// [текст посилання](https://)))*Якщо* папки venv немає перейдіть у термінал і використайте команду
#
# `python -m venv venv`
#
# ![Screenshot from 2022-12-25 13-55-03.png](data:image/png;base64,...)

# %% [markdown]
# ## Завдання 2
#
#
# > Активуйте віртуальне оточення
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# В терміналі має зявитися приставка (venv)

# %% [markdown]
# ## Завдання 3
#
#
# > Перевірте чи встановлений менеджер пакетів PIP
# Команда:
# `pip`
#
# Термінал має вивести:
#
# ![Screenshot from 2022-12-25 13-58-46.png](data:image/png;base64,...)

# %% [markdown]
# ## Завдання 4
#
#
# > Виведіть всі пакети що встановлені у вашому віртуальному оточенні командною: `pip list`
# Зробіть скриншот і додайте його до вашого ДЗ
#
# Мій результат:
#
# ![Screenshot from 2022-12-25 14-09-03.png](data:image/png;base64,...)

# %% [markdown]
# Усе працює

# %% [markdown]
# ![pythonProject6 – main.py 30.12.2022 2_36_23.png](data:image/png;base64,...)
